# %%
import pandas as pd

# %%
df=pd.read_csv("Headline Data.csv")

# %%
df
# Out:
#         Unnamed: 0                                            Article  \
# 0                0        And never more so than in Showtime’s new...
# 1                1        AlphaGo’s victory isn’t a defeat for hum...
# 2                2        Super Deluxe built a weird internet empi...
# 3                3        Steven Yang quit his job at Google in th...
# 4                4        Ahead of Black Panther’s 2018 theatrical...
# 5                5        Inside the big business of imagining the...
# 6                6        To get to the Panoptic Studio at Carnegi...
# 7                7        The Verge 2021In celebration of our 5th ...
# 8                8        The Verge 2021In celebration of our 5th ...
# 9                9        The Verge 2021In celebration of our 5th ...
# 10              10        The Verge 2021In celebration of our 5th ...
# 11              11        The Verge 2021In celebration of our 5th ...
# ...

# %%
count=0
art=[]
head=[]
for i in range(len(df["Articles"])):
    if len(df["Articles"][i]) >= 30:
        art.append(df["Articles"][i])
        head.append(df["Headline"][i])
        count+=1
print(count)
# Out:
# 184230

# %%
len(art)
# Out:
# 184230

# %%
art[10000]
# Out:
# 'The last time Utah State\\\'s basketball team had traveled to Los Angeles to play USC was 35 years ago, long before the teams\\\' current players were born, of course. But the result after they squared off at Galen Center on Sunday was the same as in 1979, with the Trojans defeating the Aggies, this time 89-84.\', "It was USC\'s fourth consecutive victory and its fifth victory in its last six games. Utah State suffered its fourth consecutive loss.", "The Trojans\' record improved to 6-3 and the Aggies fell to 3-4.", \'USC was led by forward Nikola Jovanovic, who scored 23 points on nine-for-11 shooting, and freshman guard Jordan McLaughlin, whose 21-point scoring included converting five three-point shots.\', "Indeed, much of the Trojans\' attack came from long range, with USC shooting 12 for 26 (46.2%) from three-point distance.", \'But USC also outscored Utah State in the paint, 36 points to 26, and "we had 22 assists and only nine turnovers, which is outstanding," Coach Andy Enfi
# ...

# %%
len(df["Articles"])
# Out:
# 188150

# %%
len(df["Headline"])
# Out:
# 188150

# %%
df=pd.DataFrame(art,columns=["Article"])

# %%
df["Headline"]=head

# %%
df.head()
# Out:
#                                              Article  \
# 0        And never more so than in Showtime’s new...
# 1        AlphaGo’s victory isn’t a defeat for hum...
# 2        Super Deluxe built a weird internet empi...
# 3        Steven Yang quit his job at Google in th...
# 4        Ahead of Black Panther’s 2018 theatrical...
#
#                                             Headline
# 0  Agent Cooper in Twin Peaks is the audience: on...
# 1                                  AI, the humanity!
# 2                                  The Viral Machine
# 3  How Anker is beating Apple and Samsung at thei...
# 4  Tour Black Panther’s reimagined homeland with ...

# %%
len(df["Article"])
# Out:
# 184230

# %%
count=0
art=[]
head=[]
for i in range(len(df["Headline"])):
    if len(df["Headline"][i]) >= 15:
        art.append(df["Article"][i])
        head.append(df["Headline"][i])
        count+=1
print(count)
# Out:
# 183026

# %%
df=pd.DataFrame(art,columns=["Article"])

# %%
df["Headline"]=head

# %%
df.to_csv("Cleaned Data.csv",index=None)
